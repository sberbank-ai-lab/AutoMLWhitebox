# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from autowoe import AutoWoE

# %%
import autowoe
autowoe.__version__
# Out:
# '1.3.0'

# %% [markdown]
# # Prepare Dataset

# %%
df = pd.read_csv("./data/regression_dataset.csv")

# %%
TARGET_NAME = "Target"

# %%
train_df, test_df = train_test_split(df, test_size=0.4, random_state=42, shuffle=True)

# %%
train_df[TARGET_NAME].mean(), test_df[TARGET_NAME].mean()
# Out:
# (7.414631748745448, 7.417039712211102)

# %% [markdown]
# # Train model

# %%
autowoe = AutoWoE(
    task="REG",
    monotonic=True,
    interpreted_model=True,
    regularized_refit=True,
    metric_th=0.0,
    n_jobs=1,
    verbose=0,
)

autowoe.fit(train=train_df, target_name=TARGET_NAME)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000228 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1542
# [LightGBM] [Info] Number of data points in the train set: 480, number of used features: 56
# [LightGBM] [Info] Start training from score -0.039910
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
train_pred = autowoe.predict(train_df) 
test_pred = autowoe.predict(test_df)

# %%
train_pred = autowoe.predict(train_df)

# %%
train_df
# Out:
#      Cat_0  Cat_1  Cat_10  Cat_11  Cat_12  Cat_13  Cat_14  Cat_15  Cat_16  \
# 24       1     -1      11      13       2       4       2       2       3
# 467      1     -1      11      13       1       4       2       2       3
# 539      1     -1      12      14       1       4       1       3       3
# 531      1     -1      11      13       3       4       2       0       3
# 618      1     -1       8      10       2       4       1       3       3
# ..     ...    ...     ...     ...     ...     ...     ...     ...     ...
# 106      1     -1       8      10       2       4       1       3       3
# 270      1     -1      11      13      -1       4       2       0       1
# 860      1     -1       8      10       2       4       2       3       1
# 435      1     -1       4       5      -1       4       2       2       3
# 102      1     -1       8      10       1       2       1       2       3
#
#      Cat_17  ...  Real_28    Real_3    Real_4    Real_5    Real_6    Real_7  \
# 24        0  ...     0.75  0.000000  0.666667  0.428571  0.816667  0.099220
# 467       3  ...     0.75  0.588235  0.666667  0.428571  0.933333  0.002835
# 539       1  ...     0.75  0.352941  0.555556  0.428571  0.200000  0.119064
# 531       2  ...     0.75  0.000000  0.777778  0.428571  0.966667  0.000000
# 618       3  ...     1.00  0.000000  0.555556  0.714286  0.933333  0.173990
# ..      ...  ...      ...       ...       ...       ...       ...       ...
# 106       3  ...     0.75  0.000000  0.555556  0.857143  0.916667  0.077782
# 270       1  ...     0.00  0.000000  1.000000  0.428571  0.933333  0.245571
# 860       1  ...     0.75  0.235294  0.444444  0.428571  0.283333  0.044118
# 435       3  ...     0.50  0.235294  0.666667  0.571429  0.950000  0.000000
# 102       1  ...     0.25  0.000000  0.666667  0.571429  0.383333  0.333097
#
#        Real_8    Real_9    Target  Target.1
# 24   0.000000  0.372860  7.560080  7.560080
# 467  0.000000  0.569349  7.501082  7.501082
# 539  0.468114  0.000000  7.473069  7.473069
# 531  0.000000  0.875856  8.222822  8.222822
# 618  0.000000  0.076627  7.588324  7.588324
# ..        ...       ...       ...       ...
# 106  0.320217  0.049229  7.352441  7.352441
# 270  0.000000  0.295377  8.444622  8.444622
# 860  0.518318  0.000000  7.522941  7.522941
# 435  0.000000  0.348031  7.630219  7.630219
# 102  0.000000  0.146832  7.799753  7.799753
#
# [600 rows x 65 columns]

# %%
print("Train R2 = {:.3f}".format(r2_score(train_df[TARGET_NAME], train_pred)))
print("Test R2  = {:.3f}".format(r2_score(test_df[TARGET_NAME], test_pred)))
# Out:
# Train R2 = 0.827
# Test R2  = 0.793

# %% [markdown]
# # Example of SQL-query

# %%
query = autowoe.get_sql_inference_query("FEATURE_TABLE")
print(query)
# Out:
# SELECT
#  ( 7.415 * (
#     0.0
#     +0.275*WOE_TAB.Target.1
#     +0.175*WOE_TAB.Real_4
#     +0.176*WOE_TAB.Real_13
#     +0.099*WOE_TAB.Real_2
#     +0.027*WOE_TAB.Real_19
#     +0.257*WOE_TAB.Real_10
#     +0.098*WOE_TAB.Real_6
#     +0.125*WOE_TAB.Real_18
#     +0.063*WOE_TAB.Real_21
#     +0.095*WOE_TAB.Real_1
#     +0.305*WOE_TAB.Real_7
#     +0.281*WOE_TAB.Real_11
#     +0.193*WOE_TAB.Real_0
#     +0.33*WOE_TAB.Cat_21
#     +0.183*WOE_TAB.Cat_29
#     +0.163*WOE_TAB.Real_20
#     +0.248*WOE_TAB.Cat_33
#     +0.0*WOE_TAB.Cat_22
#     +0.015*WOE_TAB.Real_22
#     +0.129*WOE_TAB.Cat_13
#     +0.338*WOE_TAB.Cat_5
#     +0.37*WOE_TAB.Real_24
#     +0.462*WOE_TAB.Cat_24
# ) + 0.411
#  ) as PROB,
#   WOE_TAB.*
# FROM
#     (SELECT
#     CASE
#       WHEN (Target.1 IS NULL OR Target.1 = 'NaN') THEN 0
#       WHEN Target.1 <= 7.42207 THEN -0.765
#       ELSE 0.802
#     END AS Target.1,
#     CASE
#       WHEN (Real_4 IS NULL OR Real_4 = 'NaN') THEN 0
#       WHEN Real_4 <= 0.61111 THEN -0.55
#       ELSE 0.866
#     END AS Real_4,
#     CASE
#       WHEN (Real_13 IS NULL OR Real_13 = 'NaN') THEN 0
#       WHEN Real_13 <= 0.20328 THEN -0.718
#       ELSE 0.58
#     END AS Real_13,
#     CASE
#       WHEN (Real_2 IS NULL OR Real_2 = 'NaN') THEN -1.296
#       WHEN Real_2 <= 0.52058 THEN -0.366
#       ELSE 0.726
#     END AS Real_2,
#     CASE
#       WHEN (Real_19 IS NULL OR Real_19 = 'NaN') THEN 0
#       WHEN Real_19 <= 0.27151 THEN -0.849
#       ELSE 0.376
#     END AS Real_19,
#     CASE
#       WHEN (Real_10 IS NULL OR Real_10 = 'NaN') THEN 0
#       WHEN Real_10 <= 0.18061 THEN -0.445
#       ELSE 0.692
#     END AS Real_10,
#     CASE
#       WHEN (Real_6 IS NULL OR Real_6 = 'NaN') THEN 0
#       WHEN Real_6 <= 0.55833 THEN -0.595
#       ELSE 0.434
#     END AS Real_6,
#     CASE
#       WHEN (Real_18 IS NULL OR Real_18 = 'NaN') THEN 0
#       WHEN Real_18 <= 0.45 THEN -0.462
#       ELSE 0.528
#     END AS Real_18,
#     CASE
#       WHEN (Real_21 IS NULL OR Real_21 = 'NaN') THEN 0
#       WHEN Real_21 <= 0.04685 THEN -0.443
#       ELSE 0.47
#     END AS Real_21,
#     CASE
#       WHEN (Real_1 IS NULL OR Real_1 = 'NaN') THEN 0.916
#       WHEN Real_1 <= -0.5182 THEN -0.361
#       ELSE 0.53
#     END AS Real_1,
#     CASE
#       WHEN (Real_7 IS NULL OR Real_7 = 'NaN') THEN 0
#       WHEN Real_7 <= 0.16708 THEN -0.17
#       ELSE 0.99
#     END AS Real_7,
#     CASE
#       WHEN (Real_11 IS NULL OR Real_11 = 'NaN') THEN 0
#       WHEN Real_11 <= 0.36755 THEN -0.216
#       ELSE 0.765
#     END AS Real_11,
#     CASE
#       WHEN (Real_0 IS NULL OR Real_0 = 'NaN') THEN 0.144
#       WHEN Real_0 <= 0.04339 THEN -0.413
#       ELSE 0.464
#     END AS Real_0,
#     CASE
#       WHEN (Cat_21 IS NULL OR Cat_21 = 'NaN') THEN 0
#       WHEN Cat_21 <= 0.0 THEN -1.472
#       ELSE 0.097
#     END AS Cat_21,
#     CASE
#       WHEN (Cat_29 IS NULL OR LOWER(CAST(Cat_29 AS VARCHAR(50))) = 'nan') THEN 0
#       WHEN Cat_29 IN (0, 1) THEN -1.131
#       WHEN Cat_29 = 2 THEN 0.112
#       ELSE None
#     END AS Cat_29,
#     CASE
#       WHEN (Real_20 IS NULL OR Real_20 = 'NaN') THEN 0
#       WHEN Real_20 <= 0.1044 THEN -0.292
#       WHEN Real_20 <= 0.16621 THEN 0.118
#       WHEN Real_20 <= 0.6772 THEN 0.424
#       ELSE 1.008
#     END AS Real_20,
#     CASE
#       WHEN (Cat_33 IS NULL OR Cat_33 = 'NaN') THEN 0
#       WHEN Cat_33 <= 4.5 THEN -0.111
#       ELSE 1.054
#     END AS Cat_33,
#     CASE
#       WHEN (Cat_22 IS NULL OR LOWER(CAST(Cat_22 AS VARCHAR(50))) = 'nan') THEN 0
#       WHEN Cat_22 = 1 THEN -1.353
#       WHEN Cat_22 = 4 THEN 0.098
#       ELSE -0.882
#     END AS Cat_22,
#     CASE
#       WHEN (Real_22 IS NULL OR Real_22 = 'NaN') THEN 0
#       WHEN Real_22 <= 0.0 THEN 0.116
#       ELSE -0.721
#     END AS Real_22,
#     CASE
#       WHEN Cat_13 = 1 THEN -1.464
#       WHEN Cat_13 = 2 THEN -0.135
#       WHEN Cat_13 = 4 THEN 0.052
#       ELSE 0
#     END AS Cat_13,
#     CASE
#       WHEN Cat_5 IN (0, 2, 4) THEN -0.055
#       WHEN Cat_5 = 1 THEN 0.749
#       ELSE 0
#     END AS Cat_5,
#     CASE
#       WHEN (Real_24 IS NULL OR Real_24 = 'NaN') THEN 0
#       WHEN Real_24 <= 0.30244 THEN -0.042
#       ELSE 0.569
#     END AS Real_24,
#     CASE
#       WHEN (Cat_24 IS NULL OR Cat_24 = 'NaN') THEN 0
#       WHEN Cat_24 <= 1.5 THEN -0.547
#       WHEN Cat_24 <= 4.5 THEN -0.424
#       ELSE 0.033
#     END AS Cat_24
#   FROM FEATURE_TABLE) as WOE_TAB

# %%
list(range(0, 0, -1))
# Out:
# []

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'
